# %% [markdown]
# # Airbnb House Analysis and Recommender Application

# %% [markdown]
# ##### Jie Bao, Kuangyi Zhang, Lanny Xu
# ##### Dr. Bamshad Mobasher, Spring 2018

# %% [markdown]
# ## Import Library

# %%
# %pylab inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import *
from sklearn import neighbors, tree, naive_bayes, cross_validation
from sklearn.cross_validation import KFold
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet, SGDRegressor
from sklearn import preprocessing
import operator
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/Lanny/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/Lanny/anaconda2/lib/python2.7/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# /Users/Lanny/anaconda2/lib/python2.7/site-packages/sklearn/learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %% [markdown]
# ## Read in data and preprocessing

# %%
listings = pd.read_table("listings_edited.csv", header='infer', delimiter=",")
print listings.shape
listings.head(5)
# Out:
# (5207, 39)
#          id                            listing_url  \
# 0  13824783  https://www.airbnb.com/rooms/13824783
# 1  16740225  https://www.airbnb.com/rooms/16740225
# 2  18125245  https://www.airbnb.com/rooms/18125245
# 3   8362570   https://www.airbnb.com/rooms/8362570
# 4    789867    https://www.airbnb.com/rooms/789867
#
#                                                 name  \
# 0      Full floor of a city cottage (up to 4 guests)
# 1                    Guest Room of Two Bedroom Condo
# 2           Cozy, spacious 2 flat in Lincoln Square!
# 3                          Lincoln Square Ravenswood
# 4  Cozy Private Room in a Classic Chicago Appartm...
#
#                                              summary  \
# 0  This 3rd-floor garrett apartment (built-out at...
# 1  Warm and secure room in a Two Bedroom Condo lo...
# 2  This cute, spacious 2 flat in Lincoln Square i...
# 3  Lincoln square, Ravenswood and Andersonville g...
# 4  $40 OFF COUPON FOR ALL NEW AIRBNB GUESTS - VIS...
#
#                                          picture_url  host_response_time  \
# 0  https://a0.muscache.com/im/pictures/510d45f8-e...      within an hour
# 1  https://a0.muscache.com/im/pictures/697182d3-d...      within an hour
# 2  https://a0.muscache.com/im/pictures/bf761217-c...      within an hour
# 3  https://a0.muscache.com/im/pictures/224a38c0-a...  within a few hours
# 4  https://a0.muscache.com/im/pictures/72031963/0...      within an hour
#
#   host_response_rate host_is_superhost host_identity_verified  \
# 0               100%                 t                      t
# 1               100%                 f                      t
# 2               100%                 f                      t
# 3               100%                 t                      t
# 4               100%                 f                      t
#
#   neighbourhood_cleansed        ...        review_scores_rating  \
# 0         Lincoln Square        ...                        99.0
# 1         Lincoln Square        ...                         NaN
# 2         Lincoln Square        ...                        95.0
# 3         Lincoln Square        ...                        98.0
# 4         Lincoln Square        ...                        94.0
#
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                   10.0                      10.0                  10.0
# 1                    NaN                       NaN                   NaN
# 2                   10.0                      10.0                  10.0
# 3                   10.0                      10.0                  10.0
# 4                    9.0                       9.0                  10.0
#
#   review_scores_communication  review_scores_location  review_scores_value  \
# 0                        10.0                    10.0                 10.0
# 1                         NaN                     NaN                  NaN
# 2                        10.0                    10.0                 10.0
# 3                        10.0                    10.0                 10.0
# 4                        10.0                    10.0                  9.0
#
#    instant_bookable  cancellation_policy reviews_per_month
# 0                 t             moderate              2.57
# 1                 t               strict               NaN
# 2                 f             moderate              4.00
# 3                 f             flexible              0.87
# 4                 t               strict              1.96
#
# [5 rows x 39 columns]

# %%
listings.describe(include="all").T
# Out:
#                             count unique  \
# id                           5207    NaN
# listing_url                  5207   5207
# name                         5206   5169
# summary                      5125   4841
# picture_url                  5207   5202
# host_response_time           4951      4
# host_response_rate           4951     55
# host_is_superhost            5207      2
# host_identity_verified       5207      2
# neighbourhood_cleansed       5207     72
# state                        5207      3
# city                         5207     14
# zipcode                      5146     63
# property_type                5207     19
# room_type                    5207      3
# accommodates                 5207    NaN
# bathrooms                    5201    NaN
# bedrooms                     5206    NaN
# beds                         5204    NaN
# bed_type                     5207      5
# amenities                    5207   4843
# price                        5207    337
# security_deposit             1999     65
# cleaning_fee                 3917    111
# guests_included              5207    NaN
# extra_people                 5207     63
# minimum_nights               5207    NaN
# maximum_nights               5207    NaN
# number_of_reviews            5207    NaN
# review_scores_rating         4469    NaN
# review_scores_accuracy       4466    NaN
# review_scores_cleanliness    4466    NaN
# review_scores_checkin        4460    NaN
# review_scores_communication  4464    NaN
# review_scores_location       4460    NaN
# review_scores_value          4457    NaN
# instant_bookable             5207      2
# cancellation_policy          5207      5
# reviews_per_month            4497    NaN
#
#                                                                            top  \
# id                                                                         NaN
# listing_url                               https://www.airbnb.com/rooms/6558625
# name                                          Wells St Suites - Old Town 3 Bed
# summary                      This property offers luxury in Chicago’s trend...
# picture_url                  https://a0.muscache.com/im/pictures/70087089/b...
# host_response_time                                              within an hour
# host_response_rate                                                        100%
# host_is_superhost                                                            f
# host_identity_verified                                                       t
# neighbourhood_cleansed                                               West Town
# state                                                                       IL
# city                                                                   Chicago
# zipcode                                                                  60647
# property_type                                                        Apartment
# room_type                                                      Entire home/apt
# accommodates                                                               NaN
# bathrooms                                                                  NaN
# bedrooms                                                                   NaN
# beds                                                                       NaN
# bed_type                                                              Real Bed
# amenities                                                                   {}
# price                                                                   $75.00
# security_deposit                                                       $100.00
# cleaning_fee                                                            $50.00
# guests_included                                                            NaN
# extra_people                                                             $0.00
# minimum_nights                                                             NaN
# maximum_nights                                                             NaN
# number_of_reviews                                                          NaN
# review_scores_rating                                                       NaN
# review_scores_accuracy                                                     NaN
# review_scores_cleanliness                                                  NaN
# review_scores_checkin                                                      NaN
# review_scores_communication                                                NaN
# review_scores_location                                                     NaN
# review_scores_value                                                        NaN
# instant_bookable                                                             f
# cancellation_policy                                                     strict
# reviews_per_month                                                          NaN
#
#                              freq        mean          std   min          25%  \
# id                            NaN  1.1491e+07  5.32038e+06  2384  7.24207e+06
# listing_url                     1         NaN          NaN   NaN          NaN
# name                            3         NaN          NaN   NaN          NaN
# summary                        23         NaN          NaN   NaN          NaN
# picture_url                     3         NaN          NaN   NaN          NaN
# host_response_time           3257         NaN          NaN   NaN          NaN
# host_response_rate           3873         NaN          NaN   NaN          NaN
# host_is_superhost            3840         NaN          NaN   NaN          NaN
# host_identity_verified       4093         NaN          NaN   NaN          NaN
# neighbourhood_cleansed        729         NaN          NaN   NaN          NaN
# state                        5204         NaN          NaN   NaN          NaN
# city                         5176         NaN          NaN   NaN          NaN
# zipcode                       461         NaN          NaN   NaN          NaN
# property_type                3502         NaN          NaN   NaN          NaN
# room_type                    3095         NaN          NaN   NaN          NaN
# accommodates                  NaN     3.79931       2.5118     1            2
# bathrooms                     NaN     1.28754     0.575582     0            1
# bedrooms                      NaN     1.44276      0.91675     0            1
# beds                          NaN     1.91295      1.36128     1            1
# bed_type                     5042         NaN          NaN   NaN          NaN
# amenities                      23         NaN          NaN   NaN          NaN
# price                         166         NaN          NaN   NaN          NaN
# security_deposit              390         NaN          NaN   NaN          NaN
# cleaning_fee                  402         NaN          NaN   NaN          NaN
# guests_included               NaN     1.84828      1.47642     1            1
# extra_people                 2362         NaN          NaN   NaN          NaN
# minimum_nights                NaN     3.40772      11.5814     1            1
# maximum_nights                NaN      413167  2.97602e+07     1           30
# number_of_reviews             NaN     25.3787       38.665     0            2
# review_scores_rating          NaN      95.043       6.1651    20           93
# review_scores_accuracy        NaN     9.70399     0.655867     2           10
# review_scores_cleanliness     NaN     9.52553     0.790706     2            9
# review_scores_checkin         NaN     9.84484     0.481231     2           10
# review_scores_communication   NaN     9.86313     0.428476     2           10
# review_scores_location        NaN     9.59865     0.727752     2            9
# review_scores_value           NaN     9.57213     0.691552     2            9
# instant_bookable             3704         NaN          NaN   NaN          NaN
# cancellation_policy          2235         NaN          NaN   NaN          NaN
# reviews_per_month             NaN     2.09054      1.86013  0.01         0.65
#
#                                      50%          75%          max
# id                           1.30835e+07  1.57733e+07  1.86568e+07
# listing_url                          NaN          NaN          NaN
# name                                 NaN          NaN          NaN
# summary                              NaN          NaN          NaN
# picture_url                          NaN          NaN          NaN
# host_response_time                   NaN          NaN          NaN
# host_response_rate                   NaN          NaN          NaN
# host_is_superhost                    NaN          NaN          NaN
# host_identity_verified               NaN          NaN          NaN
# neighbourhood_cleansed               NaN          NaN          NaN
# state                                NaN          NaN          NaN
# city                                 NaN          NaN          NaN
# zipcode                              NaN          NaN          NaN
# property_type                        NaN          NaN          NaN
# room_type                            NaN          NaN          NaN
# accommodates                           3            5           16
# bathrooms                              1          1.5            8
# bedrooms                               1            2           10
# beds                                   1            2           16
# bed_type                             NaN          NaN          NaN
# amenities                            NaN          NaN          NaN
# price                                NaN          NaN          NaN
# security_deposit                     NaN          NaN          NaN
# cleaning_fee                         NaN          NaN          NaN
# guests_included                        1            2           15
# extra_people                         NaN          NaN          NaN
# minimum_nights                         2            2          365
# maximum_nights                      1125         1125  2.14748e+09
# number_of_reviews                     11           32          410
# review_scores_rating                  97          100          100
# review_scores_accuracy                10           10           10
# review_scores_cleanliness             10           10           10
# review_scores_checkin                 10           10           10
# review_scores_communication           10           10           10
# review_scores_location                10           10           10
# review_scores_value                   10           10           10
# instant_bookable                     NaN          NaN          NaN
# cancellation_policy                  NaN          NaN          NaN
# reviews_per_month                   1.55         3.02        13.53

# %%
listings.dtypes
# Out:
# id                               int64
# listing_url                     object
# name                            object
# summary                         object
# picture_url                     object
# host_response_time              object
# host_response_rate              object
# host_is_superhost               object
# host_identity_verified          object
# neighbourhood_cleansed          object
# state                           object
# city                            object
# zipcode                         object
# property_type                   object
# room_type                       object
# accommodates                     int64
# bathrooms                      float64
# bedrooms                       float64
# beds                           float64
# bed_type                        object
# amenities                       object
# price                           object
# security_deposit                object
# cleaning_fee                    object
# guests_included                  int64
# extra_people                    object
# minimum_nights                   int64
# maximum_nights                   int64
# number_of_reviews                int64
# review_scores_rating           float64
# review_scores_accuracy         float64
# review_scores_cleanliness      float64
# review_scores_checkin          float64
# review_scores_communication    float64
# review_scores_location         float64
# review_scores_value            float64
# instant_bookable                object
# cancellation_policy             object
# reviews_per_month              float64
# dtype: object

# %%
# Id, Listing_url,Name, Summary, Picture_url
# Host_response_time, Host_response_rate, Host_identity_verified, Neighbourhood_cleansed
# City, State, Zipcode
# Property_type, Room_type, Accommodates, Bathrooms, bedrooms, Beds, Bed_type,
# Amenities: TV, wireless internet, air condition, heating, pets, washer, dryer
# Price, Security_deposit, Cleaning_fee, Guests_included, extra_people, minimum_nights, maximum_nights
# Number_of_reviews, Review_scores_rating, Instant_bookable, Cancellation_policy, reviews_per_month

# %%
# drop Listing_url, Name, Summary, Picture_url, neighbourhood_cleansed, state, city, zipcode
listings_edit = listings.drop(['listing_url', 'name', 'summary', 'picture_url', 'state', 'city', 'zipcode', 'neighbourhood_cleansed', 'reviews_per_month'], axis=1)

# %%
# Handle missing values. review_scores_rating review_scores_accuracy/_cleanliness/_checkin/_communication/_location/_value
listings_edit = listings_edit.dropna(subset=['review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value'])

# %%
listings_edit.shape
# Out:
# (4454, 30)

# %%
#only deal with the objects now

obj_listings_edit = listings_edit.select_dtypes(include=['object']).copy()
obj_listings_edit.head()
# Out:
#    host_response_time host_response_rate host_is_superhost  \
# 0      within an hour               100%                 t
# 2      within an hour               100%                 f
# 3  within a few hours               100%                 t
# 4      within an hour               100%                 f
# 5      within an hour               100%                 f
#
#   host_identity_verified property_type     room_type  bed_type  \
# 0                      t         House  Private room  Real Bed
# 2                      t     Townhouse  Private room  Real Bed
# 3                      t   Condominium  Private room  Real Bed
# 4                      t     Apartment  Private room  Real Bed
# 5                      t   Condominium  Private room  Real Bed
#
#                                            amenities   price security_deposit  \
# 0  {TV,"Cable TV","Wireless Internet","Air condit...  $56.00              NaN
# 2  {TV,"Cable TV",Internet,"Wireless Internet","A...  $80.00          $150.00
# 3  {TV,"Cable TV",Internet,"Wireless Internet","A...  $80.00              NaN
# 4  {TV,"Cable TV",Internet,"Wireless Internet","A...  $20.00              NaN
# 5  {TV,"Wireless Internet","Air conditioning",Kit...  $28.00              NaN
#
#   cleaning_fee extra_people instant_bookable cancellation_policy
# 0       $30.00       $15.00                t            moderate
# 2       $65.00       $15.00                f            moderate
# 3       $10.00       $10.00                f            flexible
# 4          NaN       $10.00                t              strict
# 5       $35.00       $20.00                t              strict

# %%
# 方法1 手动输入
# host_response_time fill nan to none
listings_edit = listings_edit.fillna({"host_response_time": "none"})

# %%
# check how many types are there
listings_edit["host_response_time"].value_counts()
# Out:
# within an hour        2865
# within a few hours     802
# within a day           580
# none                   181
# a few days or more      26
# Name: host_response_time, dtype: int64

# %%
# 手动给值
response_time_num = {"host_response_time":     {"within an hour": 1, "within a few hours": 2, 
                    "within a day": 3, "a few days or more": 4, "none": 5}}

# %%
# 直接在表里替换掉
listings_edit.replace(response_time_num, inplace=True)

# %%
# 检查看看
listings_edit["host_response_time"].value_counts()
# Out:
# 1    2865
# 2     802
# 3     580
# 5     181
# 4      26
# Name: host_response_time, dtype: int64

# %%
listings_edit = listings_edit.fillna({"host_is_superhost": "none"})
listings_edit["host_is_superhost"].value_counts()
# Out:
# f    3154
# t    1300
# Name: host_is_superhost, dtype: int64

# %%
superhost_num = {"host_is_superhost": {"t": 1, "f": 2}}
listings_edit.replace(superhost_num, inplace=True)

# %%
listings_edit["host_is_superhost"].value_counts()
# Out:
# 2    3154
# 1    1300
# Name: host_is_superhost, dtype: int64

# %%
# 方法2： 用sklearn的library种label encoder
# 直接在原始表格后添加一列新生成的0 或 1， 我个人更倾向于第二种和第三种
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
listings_edit["host_id_verified"] = le.fit_transform(listings_edit["host_identity_verified"])
listings_edit[["host_identity_verified", "host_id_verified"]].head(11)
# Out:
#    host_identity_verified  host_id_verified
# 0                       t                 1
# 2                       t                 1
# 3                       t                 1
# 4                       t                 1
# 5                       t                 1
# 6                       t                 1
# 7                       t                 1
# 10                      t                 1
# 11                      t                 1
# 12                      t                 1
# 13                      f                 0

# %%
listings_edit["property_type_code"] = le.fit_transform(listings_edit["property_type"])
listings_edit[["property_type", "property_type_code"]].head(11)
# Out:
#    property_type  property_type_code
# 0          House                  10
# 2      Townhouse                  16
# 3    Condominium                   5
# 4      Apartment                   0
# 5    Condominium                   5
# 6      Apartment                   0
# 7      Apartment                   0
# 10     Apartment                   0
# 11         House                  10
# 12     Apartment                   0
# 13     Apartment                   0

# %%
listings_edit["room_type_code"] = le.fit_transform(listings_edit["room_type"])
listings_edit[["room_type", "room_type_code"]].head(11)
# Out:
#           room_type  room_type_code
# 0      Private room               1
# 2      Private room               1
# 3      Private room               1
# 4      Private room               1
# 5      Private room               1
# 6      Private room               1
# 7      Private room               1
# 10  Entire home/apt               0
# 11  Entire home/apt               0
# 12  Entire home/apt               0
# 13  Entire home/apt               0

# %%
listings_edit["bed_type_code"] = le.fit_transform(listings_edit["bed_type"])
listings_edit[["bed_type", "bed_type_code"]].head(11)
# Out:
#     bed_type  bed_type_code
# 0   Real Bed              4
# 2   Real Bed              4
# 3   Real Bed              4
# 4   Real Bed              4
# 5   Real Bed              4
# 6      Futon              2
# 7   Real Bed              4
# 10  Real Bed              4
# 11  Real Bed              4
# 12     Futon              2
# 13  Real Bed              4

# %%
# 方法3：用panda的Label Encoding
# 同样是加在原始表格后面，不影响原数值

listings_edit["instant_bookable"] = listings_edit["instant_bookable"].astype('category')
listings_edit["instant_bookable_cat"] = listings_edit["instant_bookable"].cat.codes
listings_edit.head()
# Out:
#          id  host_response_time host_response_rate  host_is_superhost  \
# 0  13824783                   1               100%                  1
# 2  18125245                   1               100%                  2
# 3   8362570                   2               100%                  1
# 4    789867                   1               100%                  2
# 5  16701336                   1               100%                  2
#
#   host_identity_verified property_type     room_type  accommodates  bathrooms  \
# 0                      t         House  Private room             4        1.0
# 2                      t     Townhouse  Private room             6        1.5
# 3                      t   Condominium  Private room             2        1.0
# 4                      t     Apartment  Private room             3        1.0
# 5                      t   Condominium  Private room             2        1.0
#
#    bedrooms          ...           review_scores_communication  \
# 0       1.0          ...                                  10.0
# 2       2.0          ...                                  10.0
# 3       1.0          ...                                  10.0
# 4       1.0          ...                                  10.0
# 5       1.0          ...                                  10.0
#
#   review_scores_location review_scores_value instant_bookable  \
# 0                   10.0                10.0                t
# 2                   10.0                10.0                f
# 3                   10.0                10.0                f
# 4                   10.0                 9.0                t
# 5                   10.0                10.0                t
#
#   cancellation_policy host_id_verified  property_type_code room_type_code  \
# 0            moderate                1                  10              1
# 2            moderate                1                  16              1
# 3            flexible                1                   5              1
# 4              strict                1                   0              1
# 5              strict                1                   5              1
#
#    bed_type_code  instant_bookable_cat
# 0              4                     1
# 2              4                     0
# 3              4                     0
# 4              4                     1
# 5              4                     1
#
# [5 rows x 35 columns]

# %% [markdown]
# http://pbpython.com/categorical-encoding.html
# 还有很多其他方法，我这里只选了3种

# %%
### host_response_rate Transfer to integers.

listings_edit = listings_edit.fillna({"host_response_rate": "0%"})

# %%
listings_edit['host_response_rate'] = listings_edit['host_response_rate'].str[:-1].astype('int')

# %%
listings_edit.head()
# Out:
#          id  host_response_time  host_response_rate  host_is_superhost  \
# 0  13824783                   1                 1.0                  1
# 2  18125245                   1                 1.0                  2
# 3   8362570                   2                 1.0                  1
# 4    789867                   1                 1.0                  2
# 5  16701336                   1                 1.0                  2
#
#   host_identity_verified property_type     room_type  accommodates  bathrooms  \
# 0                      t         House  Private room             4        1.0
# 2                      t     Townhouse  Private room             6        1.5
# 3                      t   Condominium  Private room             2        1.0
# 4                      t     Apartment  Private room             3        1.0
# 5                      t   Condominium  Private room             2        1.0
#
#    bedrooms          ...           review_scores_communication  \
# 0       1.0          ...                                  10.0
# 2       2.0          ...                                  10.0
# 3       1.0          ...                                  10.0
# 4       1.0          ...                                  10.0
# 5       1.0          ...                                  10.0
#
#   review_scores_location review_scores_value instant_bookable  \
# 0                   10.0                10.0                t
# 2                   10.0                10.0                f
# 3                   10.0                10.0                f
# 4                   10.0                 9.0                t
# 5                   10.0                10.0                t
#
#   cancellation_policy host_id_verified  property_type_code room_type_code  \
# 0            moderate                1                  10              1
# 2            moderate                1                  16              1
# 3            flexible                1                   5              1
# 4              strict                1                   0              1
# 5              strict                1                   5              1
#
#    bed_type_code  instant_bookable_cat
# 0              4                     1
# 2              4                     0
# 3              4                     0
# 4              4                     1
# 5              4                     1
#
# [5 rows x 35 columns]

# %%
### price Transfer to integers.
listings_edit = listings_edit.fillna({"price": "$0"})

# %%
listings_edit['price'] = listings_edit['price'].str.rstrip('$').astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-3c4aa7ae0646> in <module>()
# ----> 1 listings_edit['price'] = listings_edit['price'].str.rstrip('$').astype('float')
#
# /Users/Lanny/anaconda2/lib/python2.7/site-packages/pandas/util/_decorators.pyc in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# /Users/Lanny/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# /Users/Lanny/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in astype(self, dtype, **kwargs)
#    3460
#    3461     def astype(self, dtype, **kwargs):
# -> 3462         return self.apply('astype', dtype=dtype, **kwargs)
#    3463
#    3464     def convert(self, **kwargs):
#
# /Users/Lanny/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# /Users/Lanny/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in astype(self, dtype, copy, errors, values, **kwargs)
#     542     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     543         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 544                             **kwargs)
#     545
#     546     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# /Users/Lanny/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     623
#     624                 # _astype_nansafe works fine with 1-d only
# --> 625                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     626                 values = values.reshape(self.shape)
#     627
#
# /Users/Lanny/anaconda2/lib/python2.7/site-packages/pandas/core/dtypes/cast.pyc in astype_nansafe(arr, dtype, copy)
#     701
#     702     if copy:
# --> 703         return arr.astype(dtype)
#     704     return arr.view(dtype)
#     705
#
# ValueError: could not convert string to float: $78.00
